# %% [markdown]
# # Seabed Objects Dataset Overview of Images

# %% [markdown]
# This notebook contains examples of the plane, ship, and seafloor images found in the provided training, validation, and testing datasets.

# %% [markdown]
# Plane Classifications:
#    - Single engine (13)
#    - Multi-engine (25)
#    - Fractured (8)
#    - Limited detail (16)

# %% [markdown]
# Single engine example:
#
# ![30.jpg](../../data/balanced_training_validation_set/plane/30.jpg)

# %% [markdown]
# Multi-engine example:
#
# ![plane-3.png](../../data/balanced_training_validation_set/plane/plane-3.png)

# %% [markdown]
# Fractured example:
#
# ![plane-44.png](../../data/test_set/plane/plane-44.png)

# %% [markdown]
# Limited detail example:
#
# ![17.jpg](../../data/test_set/plane/17.jpg)

# %% [markdown]
# Areas of concern for computer vision application:
# - Distortion:
# ![plane-26.png](../../data/test_set/plane/plane-26.png)
#
# - Shadows:
# ![plane-21.png](../../data/balanced_training_validation_set/plane/plane-21.png)
#
# - Extra lines on image:
# ![plane-23.png](../../data/balanced_training_validation_set/plane/plane-23.png)

# %% [markdown]
# Ship Classifications:
#    - Military (21)
#    - Logistic (191)
#    - Large boat (32) unable to determine gross naval class
#    - Small (64)
#    - Limited detail (75)

# %% [markdown]
# Military ship (aircraft carrier) example:
#
# ![ship-123.png](../../data/unbalanced_training_validation_set/ship/ship-123.png)

# %% [markdown]
# Logistic ship example:
#
# ![ship-049.png](../../data/unbalanced_training_validation_set/ship/ship-049.png)

# %% [markdown]
# Logistic ship (profile) example:
#
# ![ship232.png](../../data/unbalanced_training_validation_set/ship/ship232.png)

# %% [markdown]
# Large_boat example:
#
# ![ship220.png](../../data/unbalanced_training_validation_set/ship/ship220.png)

# %% [markdown]
# Small boat example:
#
# ![ship-169.png](../../data/test_set/ship/ship-169.png)

# %% [markdown]
# Limited detail example:
#
# ![ship-072.png](../../data/test_set/ship/ship-072.png)

# %% [markdown]
# Seafloor images containing no manmade objects (579)
#
# ![floor-1.png](../../data/balanced_training_validation_set/seafloor/floor-1.png)
#
# ![floor-20.png](../../data/balanced_training_validation_set/seafloor/floor-20.png)
#
# ![floor-29.png](../../data/balanced_training_validation_set/seafloor/floor-29.png)
